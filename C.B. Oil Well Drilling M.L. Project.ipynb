# %% [markdown]
# <div style="border-radius: 15px; border: 3px solid indigo; padding: 15px;">
# <b> Reviewer's comment 5 </b>
#
# Thank you very much for the updates! I've left a couple of new comments with digit 5, but there's nothing that needs to be fixed. This is one of the hardest projects, but you did an excellent job! The project is accepted, good luck!
#
#
#
# </div>

# %% [markdown]
# <div style="border-radius: 15px; border: 3px solid indigo; padding: 15px;">
# <b> Reviewer's comment 4 </b>
#
# I've left new comments with digit 4. Please take a look :)
#
#
# </div>

# %% [markdown]
# <div style="border-radius: 15px; border: 3px solid indigo; padding: 15px;">
# <b> Reviewer's comment 3 </b>
#
# Thank you very much for sending a new version. I've left a couple of new comments with digit 3. Would you take a look? If anything seems unclear or hard, feel free to submit the unfinished project with any questions you have - we will finish it step by step together 😊
#
#
#
# </div>

# %% [markdown]
# <div style="border-radius: 15px; border: 3px solid indigo; padding: 15px;">
# <b> Reviewer's comment 2 </b>
#
# Thank you very much for the updates! There're just a couple of issues this time. Would you take a look at my new comments with digit 2?
#
#
# </div>

# %% [markdown]
# <div style="border-radius: 15px; border: 3px solid indigo; padding: 15px;">
# <b> Reviewer's comment</b>
#
# Hi, Caleb! I am a reviewer on this project. Congratulations on submitting another machine learning project! 🎉
#
#
# Before we start, I want to pay your attention to the color marking:
#
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment ✔️</b>
#
# Great solutions and ideas that can and should be used in the future are in green comments.
# </div>
#
#
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment ⚠️</b>
#
# Yellow color indicates what should be optimized. This is not necessary, but it will be great if you make changes to this project.
# </div>
#
#
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment ❌</b>
#
# Issues that need to be corrected to get right results are indicated in red comments. Note that the project cannot be accepted until these issues are resolved.
# </div>
#
# <hr>
#
# **Please, use some color other than those listed to highlight answers to my comments.**
# I would also ask you **not to change, move or delete my comments** so that it would be easier for me to navigate during the next review.
#
# In addition, my comments are defined as headings.
# They can mess up the content; however, they are convenient, since you can immediately go to them. I will remove the headings from my comments in the next review.
#
#
#
# <hr>
#
# <font color='dodgerblue'>**A few words about the project:**</font> good job on this project, thank you so much!
#
#
# - You have prepared the subsets;
#
#
# - Used linear regression to make predictions;
#
#
# - Estimated revenue;
#
#
# - Wrote a conclusion!
#
#
#
# However, there are several issues that need your attention. Would you take a look at my comments? I've also left some recommendations for improving the project.
#
#
# <hr>
#
# Please feel free to schedule a 1:1 with our tutors or TAs, join daily coworking sessions, or ask questions in the sprint channels on Discord if you need assistance.
# </div>

# %% [markdown]
# Note to reviewer: Hope everything works this time, thanks for your help! Will leave my invalid calculations there as to remember what not to do, unless they should be removed

# %% [markdown]
# # Using Machine learning for a business setting: Oilygiant Mining Company

# %% [markdown]
# Introduction: This is a project where the data from three different regions is to be tested and analyzed to find the most profitable region to drill oil wells. First the data must be loaded, and split into training and testing sets. Then we will use the linear regression model to obtain MSE and RMSE metrics. Once the best region is picked and net profit is calculated, the next step is to use bootstrapping to find the distribution of profit. Finally a 95% confidence interval will be defined and the risk of losses will be expressed as a percentage.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2>   Reviewer's comment </h2>
#
# Good introduction!
#
# </div>
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b>   Reviewer's comment </b>
#
# Please do not forget to add titles to your projects :)
#
# </div>
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2>   Reviewer's comment 2 </h2>
#
# Good!
#
# </div>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

from scipy import stats as st

# %%
data_zero = pd.read_csv('https://practicum-content.s3.us-west-1.amazonaws.com/datasets/geo_data_0.csv')
data_one = pd.read_csv('https://practicum-content.s3.us-west-1.amazonaws.com/datasets/geo_data_1.csv')
data_two = pd.read_csv('https://practicum-content.s3.us-west-1.amazonaws.com/datasets/geo_data_2.csv')

# %%
#data_zero.head()

data_zero.head()
# Out:
#       id        f0        f1        f2     product
# 0  txEyH  0.705745 -0.497823  1.221170  105.280062
# 1  2acmU  1.334711 -0.340164  4.365080   73.037750
# 2  409Wp  1.022732  0.151990  1.419926   85.265647
# 3  iJLyR -0.032172  0.139033  2.978566  168.620776
# 4  Xdl7t  1.988431  0.155413  4.751769  154.036647

# %%
#data_one.head()

data_one.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 5 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   id       100000 non-null  object
#  1   f0       100000 non-null  float64
#  2   f1       100000 non-null  float64
#  3   f2       100000 non-null  float64
#  4   product  100000 non-null  float64
# dtypes: float64(4), object(1)
# memory usage: 3.8+ MB

# %%
data_zero['id'].duplicated().sum()
# Out:
# 10

# %%
dup_d0 = data_zero[data_zero['id'].duplicated()==True]

print(dup_d0)
# Out:
#           id        f0        f1         f2     product
# 7530   HZww2  1.061194 -0.373969  10.430210  158.828695
# 41724  bxg6G -0.823752  0.546319   3.630479   93.007798
# 51970  A5aEY -0.180335  0.935548  -2.094773   33.020205
# 63593  QcMuo  0.635635 -0.473422   0.862670   64.578675
# 66136  74z30  1.084962 -0.312358   6.990771  127.643327
# 69163  AGS9W -0.933795  0.116194  -3.655896   19.230453
# 75715  Tdehs  0.112079  0.430296   3.218993   60.964018
# 90815  fiKDv  0.049883  0.841313   6.394613  137.346586
# 92341  TtcGQ  0.110711  1.022689   0.911381  101.318008
# 97785  bsk9y  0.378429  0.005837   0.160827  160.637302

# %%
data_zero['id'] = data_zero['id'].drop_duplicates()

# %%
data_one.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 5 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   id       100000 non-null  object
#  1   f0       100000 non-null  float64
#  2   f1       100000 non-null  float64
#  3   f2       100000 non-null  float64
#  4   product  100000 non-null  float64
# dtypes: float64(4), object(1)
# memory usage: 3.8+ MB

# %%
data_one.head()
# Out:
#       id         f0         f1        f2     product
# 0  kBEdx -15.001348  -8.276000 -0.005876    3.179103
# 1  62mP7  14.272088  -3.475083  0.999183   26.953261
# 2  vyE1P   6.263187  -5.948386  5.001160  134.766305
# 3  KcrkZ -13.081196 -11.506057  4.999415  137.945408
# 4  AHL4O  12.702195  -8.147433  5.004363  134.766305

# %%
data_one['id'] = data_one['id'].drop_duplicates()

# %%
#data_two.head()
data_two.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 5 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   id       100000 non-null  object
#  1   f0       100000 non-null  float64
#  2   f1       100000 non-null  float64
#  3   f2       100000 non-null  float64
#  4   product  100000 non-null  float64
# dtypes: float64(4), object(1)
# memory usage: 3.8+ MB

# %%
data_two['id'].duplicated().sum()
# Out:
# 4

# %%
data_zero = data_zero.drop('id', axis = 1)

# %%
data_zero.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 4 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   f0       100000 non-null  float64
#  1   f1       100000 non-null  float64
#  2   f2       100000 non-null  float64
#  3   product  100000 non-null  float64
# dtypes: float64(4)
# memory usage: 3.1 MB

# %%
data_one = data_one.drop('id', axis = 1)

# %%
data_two = data_two.drop('id', axis = 1)

# %%
## Histograms for Region 0
data_zero['f0'].hist()
plt.title('f0 distribution')
plt.xlabel('feature value')
plt.ylabel('quantity')
plt.show()
data_zero['f1'].hist()
plt.title('f1 distribution')
plt.xlabel('feature value')
plt.ylabel('quantity')
plt.show()
data_zero['f2'].hist()
plt.title('f2 distribution')
plt.xlabel('feature value')
plt.ylabel('quantity')
plt.show()
data_zero['product'].hist()
plt.title('product distribution')
plt.xlabel('product value')
plt.ylabel('quantity')
plt.show()

# %% [markdown]
# The distribution for region 0 product is normally distributed and centered around 90 units

# %%
## Histograms for Region 1
data_one['f0'].hist()
plt.title('f0 distribution')
plt.xlabel('feature value')
plt.ylabel('quantity')
plt.show()
data_one['f1'].hist()
plt.title('f1 distribution')
plt.xlabel('feature value')
plt.ylabel('quantity')
plt.show()
data_one['f2'].hist()
plt.title('f2 distribution')
plt.xlabel('feature value')
plt.ylabel('quantity')
plt.show()
data_one['product'].hist()
plt.title('product distribution')
plt.xlabel('product value')
plt.ylabel('quantity')
plt.show()

# %% [markdown]
# The distribution for the product in region one is not normally distributed but it is symmetrical. It is centered around 70 units

# %%
## Histograms for Region 2
data_two['f0'].hist()
plt.title('f0 distribution')
plt.xlabel('feature value')
plt.ylabel('quantity')
plt.show()
data_two['f1'].hist()
plt.title('f1 distribution')
plt.xlabel('feature value')
plt.ylabel('quantity')
plt.show()
data_two['f2'].hist()
plt.title('f2 distribution')
plt.xlabel('feature value')
plt.ylabel('quantity')
plt.show()
data_two['product'].hist()
plt.title('product distribution')
plt.xlabel('product value')
plt.ylabel('quantity')
plt.show()

# %% [markdown]
# The 'product' distribution for region 2 is normally distributed and centered around 90 units

# %%
#Q I can change graph style if needed, should I deploy the graphs after the data is scaled or does it matter?

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2>   Reviewer's comment 2 </h2>
#
# It will be harder to analyze it after we scale the data, so I would do that before scaling.
# </div>
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b>   Reviewer's comment 2 </b>
#
# Please don't forget about the conclusions.
# </div>
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2>   Reviewer's comment 3 </h2>
#
# Good!
#
# </div>

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b>   Reviewer's comment </b>
#
#
#
# - Let's add some EDA. Are there any duplicates in the `id` columns?
#
#
#
# - Let's analyze the distributions in each dataframe. Would you add charts? Please don't forget to add titles and axes labels.
# </div>

# %% [markdown]
# Once the data is loaded, calling info helps us check for missing values, as well as pick the correct column for the target. Calling duplicated().sum() helps show that there are no fully duplicated rows.

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment </b>
#
#
# We should not encode the `id` column. Instead, we should delete it, since these values do not influence anything :)
#
# </div>

# %%
def data_split_fn(df, column):

    target = df[column]
    features = df.drop(column, axis = 1)
    features_train, features_valid, target_train, target_valid = train_test_split(
    features, target, test_size=0.25, random_state=12345)

    return  features_train, features_valid, target_train, target_valid

# %%
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# from sklearn.preprocessing import StandardScaler
#
# def scale_fn(Numeric, features ):
#
#
#
#     Scaler = StandardScaler()
#     Scaler.fit(features[Numeric])
#
#     features[Numeric] = Scaler.transform(features[Numeric])
#     features[Numeric] = Scaler.transform(features[Numeric])
#
#     features_train_scaled = features[Numeric]
#     features_valid_scaled = features[Numeric]
#
#     pd.options.mode.chained_assignment = None
#     print(features_train.head())
#
#     return features_train_scaled, features_valid_scaled

# %%
from sklearn.preprocessing import StandardScaler

def scale_fn(features_train, features_valid, columns):
    # Create the scaler and fit on the training set
    scaler = StandardScaler()
    scaler.fit(features_train[columns])
    
    # Transform both the training and validation data
    features_train_scaled = features_train.copy()
    features_valid_scaled = features_valid.copy()
    
    features_train_scaled[columns] = scaler.transform(features_train[columns])
    features_valid_scaled[columns] = scaler.transform(features_valid[columns])
    
    # Print head of scaled features for verification
    pd.options.mode.chained_assignment = None
    print(features_train_scaled.head())
    
    return features_train_scaled, features_valid_scaled

# Example usage
columns = ['f0', 'f1', 'f2']  # Columns to be scaled
features_train, features_valid, target_train, target_valid = data_split_fn(data_zero, 'product')

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2>   Reviewer's comment 2 </h2>
#
# Try not to repeat the code.
# </div>

# %%
def create_predictions_df(features_valid, target_valid):
    predictions = model.predict(features_valid)
    
    actual = target_valid
    
    predictions_df = pd.DataFrame({'Actual': actual, 'Predicted': predictions})
    
    return predictions_df

# %% [markdown]
# #False# The data must be ordinally encoded for it to work with the model, once encoded the target is labeled and it is split into the appropriate sets for training and validation. #From 1st draft# ##will delete upon approval##

# %%
features_train, features_valid, target_train, target_valid_0 = data_split_fn(data_zero, 'product') #2.1

# %%
features_train_scaled, features_valid_scaled_0 = scale_fn(features_train, features_valid, columns)
# Out:
#              f0        f1        f2
# 27212 -0.544828  1.390264 -0.094959
# 7866   1.455912 -0.480422  1.209567
# 62041  0.260460  0.825069 -0.204865
# 70185 -1.837105  0.010321 -0.147634
# 82230 -1.299243  0.987558  1.273181

# %% [markdown]
# 2.2

# %%
model = LinearRegression()
model.fit(features_train_scaled, target_train)
d0predicted_valid = model.predict(features_valid_scaled_0)
mse = mean_squared_error(target_valid_0, d0predicted_valid)
print('Linear Regression region 0')
print('MSE =', mse)
print('RMSE =', mse ** 0.5)
# Out:
# Linear Regression region 0
# MSE = 1412.2129364399243
# RMSE = 37.5794217150813

# %%
d0_predictions_df = create_predictions_df(features_valid_scaled_0, target_valid_0)

# %%
features_train, features_valid, target_train, target_valid_1 = data_split_fn(data_one, 'product') #2.1 contd.

# %%
features_train_scaled, features_valid_scaled_1 = scale_fn(features_train, features_valid, columns)
# Out:
#              f0        f1        f2
# 27212 -0.850855  0.624428  0.296943
# 7866   1.971935  1.832275  0.294333
# 62041  1.079305  0.170127 -0.296418
# 70185 -1.512028 -0.887837 -0.880471
# 82230 -1.804775 -0.718311 -0.293255

# %%
model = LinearRegression()
model.fit(features_train_scaled, target_train)
d1predicted_valid = model.predict(features_valid_scaled_1)
mse = mean_squared_error(target_valid_1, d1predicted_valid)
print('Linear Regression region 1')
print('MSE =', mse)
print('RMSE =', mse ** 0.5)
# Out:
# Linear Regression region 1
# MSE = 0.7976263360391157
# RMSE = 0.893099286775617

# %%
d1_predictions_df = create_predictions_df(features_valid_scaled_1, target_valid_1)

# %%
features_train, features_valid, target_train, target_valid_2 = data_split_fn(data_two, 'product') #2.1 further

# %%
features_train_scaled, features_valid_scaled_2 = scale_fn(features_train, features_valid, columns)
# Out:
#              f0        f1        f2
# 27212 -0.526160  0.776329 -0.400793
# 7866  -0.889625 -0.404070 -1.222936
# 62041 -1.133984  0.208576  0.296765
# 70185  1.227045  1.570166 -0.764556
# 82230 -0.194289  0.878312  0.840821

# %%
model = LinearRegression()
model.fit(features_train_scaled, target_train)
d2predicted_valid = model.predict(features_valid_scaled_2)
mse = mean_squared_error(target_valid_2, d2predicted_valid)
print('Linear Regression Region 2')
print('MSE =', mse)
print('RMSE =', mse ** 0.5)
# Out:
# Linear Regression Region 2
# MSE = 1602.3775813236196
# RMSE = 40.02970873393434

# %%
d2_predictions_df = create_predictions_df(features_valid_scaled_2, target_valid_2)

# %% [markdown]
# #I don't have the fancy variables I had in the first iteration but I'm hoping that Jupyter can keep track of the target_train and target_valid variables as they change each time the functions are called

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment </b>
#
#
# I would scale the data, since it may be crucial for linear models.
#
# </div>

# %% [markdown]
# #trained model named `model`
# predictions = model.predict(d0features_valid)  # X_valid is the features of your validation set
#
# #Saving the predictions and correct answers:
# #store the predictions and actual reserves (correct answers) for later comparison and analysis:
#
# actual = d0target_valid  # y_valid is the actual reserves of validation set
#
# # You can use a DataFrame to store both
# predictions0_df = pd.DataFrame({'Actual': actual, 'Predicted': predictions})

# %%
d0_predictions_df.head()
# Out:
#            Actual  Predicted
# 71751   10.038645  95.894952
# 80493  114.551489  77.572583
# 2655   132.603635  77.892640
# 53233  169.072125  90.175134
# 91141  122.325180  70.510088

# %%
d0_actual_slice = d0_predictions_df['Actual']

avg_vol_0_a= d0_actual_slice.mean()

avg_vol_0_a
# Out:
# 92.07859674082927

# %%
d0_predictions_slice = d0_predictions_df['Predicted']

avg_vol_0_p= d0_predictions_slice.mean()


avg_vol_0_p
# Out:
# 92.59256778438035

# %% [markdown]
# For region 0 the predictions are good

# %% [markdown]
# average volume is a relevant and present metric in all three regions that the instructions suggest comparing

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment </h2>
#
#
# Good.
#
# </div>

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment</b>
#
#
# Same issue here and further.
#
# </div>

# %%
d1_predictions_df.head() #good, the numbers are different. Wondering why the Id's are the same
                        #even though the regions are different
# Out:
#           Actual  Predicted
# 71751  80.859783  82.663314
# 80493  53.906522  54.431786
# 2655   30.132364  29.748760
# 53233  53.906522  53.552133
# 91141   0.000000   1.243856

# %%
d1_actual_slice = d1_predictions_df['Actual']


avg_vol_1_a= d1_actual_slice.mean()

avg_vol_1_a
# Out:
# 68.72313602435997

# %%
d1_predictions_slice = d1_predictions_df['Predicted']

avg_vol_1_p= d1_predictions_slice.mean()

avg_vol_1_p
# Out:
# 68.728546895446

# %% [markdown]
# For region one the predictions are pretty close to the actual amount of reserves!

# %% [markdown]
# The whole process must be completed 3 times, once for each region, then you can create a dataframe with the relevant metrics on the reserves, actual and predicted. ##And find the averages of both##

# %%
d2_predictions_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 25000 entries, 71751 to 43558
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Actual     25000 non-null  float64
#  1   Predicted  25000 non-null  float64
# dtypes: float64(2)
# memory usage: 585.9 KB

# %%
d2_predictions_slice = d2_predictions_df['Predicted']


avg_vol_2_p= d2_predictions_slice.mean()

avg_vol_2_p
# Out:
# 94.96504596800489

# %%
d2_actual_slice = d2_predictions_df['Actual']


avg_vol_2_a= d2_actual_slice.mean()

avg_vol_2_a
# Out:
# 94.88423280885438

# %% [markdown]
# Similar to region one the predictions of region 2 are satisfyingly close the the actual reserves in the wells.

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment</b>
#
# You can use a loop or a function, since the code is the same for all three regions.
#
# </div>
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b>   Reviewer's comment </b>
#
# What about predictions? Let's evaluate models' performance as well.
#
# </div>
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment 2 </h2>
#
#
# Good.
#
# </div>

# %%
#Calculate the volume of reserves per well required to develop a well without having losses.


#The budget for development of 200 oil wells is 100 million USD.

well_quantity = 200

budget_USD = 10e7

#The revenue from one unit of product is 4500 USD (volume  of reserves is expressed in thousands of barrels)

revenue_USD_per_unit = 4.5*10e2

break_even_value = budget_USD/well_quantity 


#500,000/4500 = 111.111 units of product per well required to break even.

minimum_product_to_profit = break_even_value/revenue_USD_per_unit 
 

minimum_for_profit = f"{minimum_product_to_profit:.2f}"

minimum_for_profit
# Out:
# '111.11'

# %%
def compare_breakeven_with_avg_reserves(avg_reserves_region, break_even_point, region):
    if avg_reserves_region < break_even_point:
        difference = break_even_point - avg_reserves_region
        
        percent = (difference/avg_reserves_region) * 100
       
        print(f"The average reserves of {region} are {percent} percent lower than the break even point")
        
    else:
        difference = avg_reserves_region - break_even_point
        
        percent = (difference/avg_reserves_region) *100
       
        print(f"The average reserves of {region} are {percent} percent higher than the break even point")

# %% [markdown]
# ##3.2

# %%
compare_breakeven_with_avg_reserves(avg_vol_0_a, minimum_product_to_profit, "Region 0")
# Out:
# The average reserves of Region 0 are 20.66985710463428 percent lower than the break even point

# %%
compare_breakeven_with_avg_reserves(avg_vol_1_a, minimum_product_to_profit, "Region 1")
# Out:
# The average reserves of Region 1 are 61.67933761306538 percent lower than the break even point

# %%
compare_breakeven_with_avg_reserves(avg_vol_2_a, minimum_product_to_profit, "Region 2")
# Out:
# The average reserves of Region 2 are 17.10176477365424 percent lower than the break even point

# %%
compare_breakeven_with_avg_reserves(120, minimum_product_to_profit, "Region 0") #this was a test
# Out:
# The average reserves of Region 0 are 7.407407407407404 percent higher than the break even point

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b>   Reviewer's comment </b>
#
# What if the task changes a little bit and we are to have different constant values? Let's use the code to calculate the break-even value.
# </div>
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment 2  </h2>
#
#
# Correct. The average volumes in these three regions are less than the required value. If we are to select the wells randomly, we are probably going to lose money.
#
#
# </div>

# %% [markdown]
# The average predicted reserves for the first and third regions are in the 90's of units when all 500 data points are considered.At the current time, is within reason that the top 200 points can average out to be above 111, but the second region barely warrants a look, with an average of 68.7 units.

# %%
d0_sample = d0_predictions_df.sample(500, random_state =12345)

d0_sample.head()
# Out:
#            Actual   Predicted
# 9900    40.482304   73.213157
# 32549   34.658642   60.426056
# 8269   133.413844  129.143890
# 32511  122.244690  109.787376
# 50015   40.699558  109.055690

# %%
d0_sorted = d0_sample.sort_values(by='Predicted', ascending=False)

# %%
top_wells = d0_sorted.head(200)

# %%
top_wells.mean()
# Out:
# Actual       118.656321
# Predicted    116.726077
# dtype: float64

# %%
r0_avg_res = d0_predictions_df['Actual'].mean()

r0_avg_res
# Out:
# 92.07859674082927

# %% [markdown]
# Once the data is simplified into the actual and predicted amounts of reserves it can be sorted in descending order and the top 200 wells can be selected out and saved in a different variable. This is where we calculate the mean of both columns for each region to determine profitabilty.

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 2 </b>
#
#
# Do you need all this code above?
#
# </div>

# %% [markdown]
# I removed the above code because it is present in the functions and function calls towards the end of the project

# %%
def calculate_profit(predictions, n_top_wells=200, price_per_barrel=4500, budget=100e6):
    # Sort the predictions DataFrame by predicted product in descending order
#sample_wells = predictions.sample(500, random_state = 12345)#I had the wrong idea here
    
    predictions_sorted = predictions.sort_values(by='Actual', ascending=False) ##changed the by = argument to Actual
    
    # Select the top n wells
    top_wells = predictions_sorted.head(n_top_wells)
    
    # Calculate the total revenue
    total_revenue = top_wells['Actual'].sum() * price_per_barrel ##Changed from Predicted to Actual
    
    # Calculate the profit (revenue minus development costs)
    profit = total_revenue - budget
    
    return profit

#Changed first line to include only sample of 500 points, It increased the risk amount and lowered profit

# %%
d1_predictions_slice = d1_predictions_df['Predicted']
d1_actual_slice = d1_predictions_df['Actual']



d2_predictions_slice = d2_predictions_df['Predicted']
d2_actual_slice = d2_predictions_df['Actual']

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 2 </b>
#
#
# We sample in bootstrapping. We do not need any sampling for profit calculation.
# </div>

# %%
region_0_profit = calculate_profit(d0_predictions_df)

region_0_profit
# Out:
# 65109475.803188115

# %%
region_1_profit = calculate_profit(d1_predictions_df)

region_1_profit
# Out:
# 24150866.966815114

# %%
region_2_profit = calculate_profit(d2_predictions_df)

region_2_profit
# Out:
# 69426631.59191746

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b>   Reviewer's comment 3 </b>
#
# Profit should not be negative. When you combine predictions and actual data, please make sure that indices match. This can be the reason why we have negative profit values.  </div>
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 4 </b>
#
#
# I believe something is wrong with the indices, so let's try to use separate dataframes. I will define a new function for profit calculation.
# </div>

# %%
# Reviewer's code 4

def calculate_profit2(target, predictions):

    predictions_sorted = predictions.sort_values(ascending=False)
    selected_points = target[predictions_sorted.index][:200]
    product = selected_points.sum()
    revenue = product * 4500
    return revenue - 1e8

# temporary variables
target_valid_0_1 = pd.Series(target_valid_0.reset_index(drop=True))
d0predicted_valid_1 = pd.Series(d0predicted_valid, index=target_valid_0_1.index)
                            
calculate_profit2(target_valid_0_1, d0predicted_valid_1)
# Out:
# 33208260.43139851

# %%
target_valid_1_1 = pd.Series(target_valid_1.reset_index(drop=True))
d1predicted_valid_1 = pd.Series(d1predicted_valid, index=target_valid_0_1.index)

calculate_profit2(target_valid_1_1, d1predicted_valid_1)
# Out:
# 24150866.966815114

# %%
target_valid_2_1 = pd.Series(target_valid_2.reset_index(drop=True))
d2predicted_valid_1 = pd.Series(d2predicted_valid, index=target_valid_2_1.index)

calculate_profit2(target_valid_2_1, d2predicted_valid_1)
# Out:
# 27103499.635998324

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment 5 </h2>
#
#
# Correct.
#
#
# So what was the problem? The logic of your code was correct, and everything was fine. However, sometimes indices do not match. That is the reason why I explicitly reset indices in the target variable and set the same indices to the predictions variable.
#
#
# Next time when you combine two arrays into one dataframe, try to check whether indices match.
# </div>
#
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment 5 </h2>
#
#
# You can use a loop here.
#
#
# </div>

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 4 </b>
#
#
# Now, let's implement bootsrtapping for one region:</div>

# %%
# Reviewer's code 4

# It is important to define state outside bootstrapping loop.
state = np.random.RandomState(123)

target = target_valid_0.reset_index(drop=True)
predictions = pd.Series(d0predicted_valid, index=target.index)


profit_values = []

# Repeat sampling 1000 times
for _ in range(1000):
    
    #Sample 500 rows with replacement
    target_sample = target.sample(500, replace=True, random_state=state)
    predictions_sample = predictions[target_sample.index]
    
    # Profit calculation, here you can call a function
    profit_values.append(calculate_profit2(target_sample, predictions_sample))
    # you can also calculate revenue right here
    
    
profit_values = pd.Series(profit_values) 

mean_profit = profit_values.mean()

# You can also use quantile
confidence_interval = np.percentile(profit_values, [2.5, 97.5]).round(2)
risk = (profit_values < 0).mean()


print("Mean profit: ", mean_profit)
print("95% confidence interval:", confidence_interval)
print(f"Risk of Loss: {risk*100:.2f}%")
# Out:
# Mean profit:  4280792.592027558
# 95% confidence interval: [-1415985.31  9601903.45]
# Risk of Loss: 7.50%

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment 5 </h2>
#
#
# By the way, if we change the `state` variable above, the results will change. This is why it is important to define it outside the bootstrapping loop.
# </div>

# %%
state = np.random.RandomState(123)

target = target_valid_1.reset_index(drop=True)
predictions = pd.Series(d1predicted_valid_1, index=target.index)


profit_values = []

# Repeat sampling 1000 times
for _ in range(1000):
    
    #Sample 500 rows with replacement
    target_sample = target.sample(500, replace=True, random_state=state)
    predictions_sample = predictions[target_sample.index]
    
    # Profit calculation, here you can call a function
    profit_values.append(calculate_profit2(target_sample, predictions_sample))
    # you can also calculate revenue right here
    
    
profit_values = pd.Series(profit_values) 

mean_profit = profit_values.mean()

# You can also use quantile
confidence_interval = np.percentile(profit_values, [2.5, 97.5]).round(2)
risk = (profit_values < 0).mean()


print("Mean profit: ", mean_profit)
print("95% confidence interval:", confidence_interval)
print(f"Risk of Loss: {risk*100:.2f}%")
# Out:
# Mean profit:  5150904.743981806
# 95% confidence interval: [1138017.2  9323048.74]
# Risk of Loss: 0.20%

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment 5 </h2>
#
#
# I recommend that you define a function or add an outer loop to iterate over the list of three regions :) In the next projects, try to avoid repetitions.
#
# </div>

# %%
state = np.random.RandomState(123)

target = target_valid_2.reset_index(drop=True)
predictions = pd.Series(d2predicted_valid_1, index=target.index)


profit_values = []

# Repeat sampling 1000 times
for _ in range(1000):
    
    #Sample 500 rows with replacement
    target_sample = target.sample(500, replace=True, random_state=state)
    predictions_sample = predictions[target_sample.index]
    
    # Profit calculation, here you can call a function
    profit_values.append(calculate_profit2(target_sample, predictions_sample))
    # you can also calculate revenue right here
    
    
profit_values = pd.Series(profit_values) 

mean_profit = profit_values.mean()

# You can also use quantile
confidence_interval = np.percentile(profit_values, [2.5, 97.5]).round(2)
risk = (profit_values < 0).mean()


print("Mean profit: ", mean_profit)
print("95% confidence interval:", confidence_interval)
print(f"Risk of Loss: {risk*100:.2f}%")
# Out:
# Mean profit:  4206914.077007624
# 95% confidence interval: [-1077348.29  9746923.49]
# Risk of Loss: 5.90%

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 4 </b>
#
#
# Would you try to repeat that for other regions?
# </div>

# %% [markdown]
# #FALSE# According to the numbers, region 0 will provide the most profit per well. The predicted difference is 7 more units of product per well, and the actual difference is also 7 units more then the next most profitable region.
# #Rewritten at end of project#

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b>   Reviewer's comment </b>
#
# Is it reliable to take the average from the top 200 points? Please try to estimate the average of their actual reserves.
#
# </div>

# %%
d0_loss_points = d0_predictions_df[d0_predictions_df['Actual'] < minimum_product_to_profit]

d0_loss_points_slice = d0_loss_points['Actual']

# %%
d0total_risk = d0_loss_points_slice.sum()

d0total_risk
# Out:
# 1030652.8712358647

# %%
d0_risk_of_losses = d0total_risk/region_0_profit

d0_percent_risk = d0_risk_of_losses * 100

d0_percent_risk
# Out:
# 1.58295372297468

# %%
d1_loss_points = d1_predictions_df[d1_predictions_df['Actual'] < minimum_product_to_profit]

d1_loss_points_slice = d1_loss_points['Actual']

# %%
d1total_risk = d1_loss_points_slice.sum()

d1total_risk
# Out:
# 1147334.113845803

# %%
d1_risk_of_losses = d1total_risk/region_1_profit

d1_percent_risk = d1_risk_of_losses * 100

d1_percent_risk
# Out:
# 4.75069534945605

# %%
d2_loss_points = d2_predictions_df[d2_predictions_df['Actual'] < minimum_product_to_profit]

d2_loss_points_slice = d2_loss_points['Actual']

# %%
d2total_risk = d2_loss_points_slice.sum()

d2total_risk
# Out:
# 1018482.9170702008

# %%
d2_risk_of_losses = d2total_risk/region_2_profit

d2_percent_risk = d2_risk_of_losses * 100

d2_percent_risk
# Out:
# 1.4669916913969525

# %% [markdown]
# Changing the profit function to sort by 'actual' while using the predictions_df made the revenue values rise, as well as changing the risk values so that they are within the threshold and it finally makes sense! I hope that was right..

# %%
# Given break-even volume for profit calculation
minimum_product_to_profit = 111.11 # Based on your earlier output

# Filtering and calculating risk of losses

# For region 0
d0_loss_points = d0_predictions_df[d0_predictions_df['Actual'] < minimum_product_to_profit]
#d0_profit_points = d0_predictions_df[d0_predictions_df['Actual'] >= minimum_product_to_profit]
#d0_loss_length = len(d0_loss_points)
#d0_profit_length = len(d0_profit_points)
#d0_loss_amount = d0_loss_points['Actual'].sum()
#d0_profit_amount = d0_profit_points['Actual'].sum()
d0_risk_of_losses = len(d0_loss_points) / len(d0_predictions_df)  # Fraction of loss points in the total samples
print(d0_risk_of_losses)

# For region 1
d1_loss_points = d1_predictions_df[d1_predictions_df['Actual'] < minimum_product_to_profit]
d1_risk_of_losses = len(d1_loss_points) / len(d1_predictions_df)
print(d1_risk_of_losses)

# For region 2#
d2_loss_points = d2_predictions_df[d2_predictions_df['Actual'] < minimum_product_to_profit]
d2_risk_of_losses = len(d2_loss_points) / len(d2_predictions_df)
print(d2_risk_of_losses)


#This was given to me by @Dot tutor, the numbers do not seem right. It still needs to be weighted. 
#Was my approach on lines 71-79 correct in its design? 
#wondering if the numbers are wrong because of an error in an earlier process/calculation
# Out:
# 0.63756
# 0.83256
# 0.61836

# %%
# For region 0
d0_loss_points = d0_predictions_df[d0_predictions_df['Actual'] < minimum_product_to_profit]
d0_risk_of_losses = len(d0_loss_points) / len(d0_predictions_df)
print(f"Region 0 Risk of Losses: {d0_risk_of_losses}")

# For region 1
d1_loss_points = d1_predictions_df[d1_predictions_df['Actual'] < minimum_product_to_profit]
d1_risk_of_losses = len(d1_loss_points) / len(d1_predictions_df)
print(f"Region 1 Risk of Losses: {d1_risk_of_losses}")

# For region 2
d2_loss_points = d2_predictions_df[d2_predictions_df['Actual'] < minimum_product_to_profit]
d2_risk_of_losses = len(d2_loss_points) / len(d2_predictions_df)
print(f"Region 2 Risk of Losses: {d2_risk_of_losses}")
# Out:
# Region 0 Risk of Losses: 0.63756
# Region 1 Risk of Losses: 0.83256
# Region 2 Risk of Losses: 0.61836

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 2 </b>
#
#
# After you change the profit function, you can move on to the bootstrapping implementation. For this purpose, please follow the steps I provided below.
#
# </div>
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b>   Reviewer's comment 3 </b>
#
# Isn't it strange that all values are the same?
# </div>
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b>   Reviewer's comment 3 </b>
#
# > `111.11111111111111`
#
#
# You do not need to store so many digits after the floating point. </div>
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment 5 </h2>
#
#
# When you introduce significant changes, the irrelevant code fragments can be deleted if you do not need them anymore. </div>

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment </b>
#
#
# We should also use target values in the revenue estimation. We indeed need to select the best 200 wells by predictions, but then we need to use target values to actually calculate profit because predictions are not necessarily accurate.
#
# </div>

# %% [markdown]
# Use revenue function to estimate profit for all 3 regions

# %%
region_0_profit = calculate_profit(d0_predictions_df)

region_0_profit
# Out:
# 65109475.803188115

# %%
region_1_profit = calculate_profit(d1_predictions_df)

region_1_profit
# Out:
# 24150866.966815114

# %%
region_2_profit = calculate_profit(d2_predictions_df)

region_2_profit
# Out:
# 69426631.59191746

# %% [markdown]
# When using the profit calculating function, region 0 is shown to return the most profit: nearly 40 million USD.
#
# ##Update: Region one now records the most profit of 7.79 million USD
#
# ##Update2: Region zero is again the best with 33.2 million USD profit

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2>   Reviewer's comment </h2>
#
# The results will change :)
# </div>

# %%
#bootstrapping with 95%confidence interval
def bootstrapping_fn(df):
    state = np.random.RandomState(12345)

    # Store the 99% quantile values to the values variable
    values = []
    for i in range(500):                    ##Question should this be 500 or 1000? I got confused by the directions
        subsample = df['Predicted'].sample(frac=1, replace=True, random_state=state)
        values.append(subsample.quantile(0.99)), 

    values = pd.Series(values)

    average_profit = values.mean()
    lower = values.quantile(0.025)
    upper = values.quantile(0.975)

    print(lower)
    print(upper)
    print(average_profit)
    
    return values

# %%
d0_sampled = bootstrapping_fn(d0_predictions_df)
# Out:
# 145.11321594962496
# 147.59857935779226
# 146.50810673135243

# %%
def calculate_final_profit(predictions, n_top_wells=200, price_per_barrel=4500, budget=100e6):
    # Sort the predictions DataFrame by predicted product in descending order
#sample_wells = predictions.sample(500, random_state = 12345)#I had the wrong idea here
    
    predictions_sorted = predictions.sort_values(ascending=False)
    
    # Select the top n wells
    top_wells = predictions_sorted.head(n_top_wells)
    
    # Calculate the total revenue
    total_revenue = top_wells.sum() * price_per_barrel ##Changed from Predicted to Actual
    
    # Calculate the profit (revenue minus development costs)
    profit = total_revenue - budget
    
    return profit

# %%
region_0_profit_final = calculate_final_profit(d0_sampled)

region_0_profit_final
# Out:
# 32365628.661267504

# %%
region_0_risk = d0total_risk/region_0_profit_final

region_0_risk
# Out:
# 0.03184405537190336

# %%
d1_sampled = bootstrapping_fn(d1_predictions_df)
# Out:
# 138.2630176083361
# 138.37406714634625
# 138.3177939587846

# %%
region_1_profit_final = calculate_final_profit(d1_sampled)

region_1_profit_final
# Out:
# 24509496.61708358

# %%
region_1_risk = d1total_risk/region_1_profit_final

region_1_risk
# Out:
# 0.046811818772568736

# %%
d2_sampled = bootstrapping_fn(d2_predictions_df)
# Out:
# 140.12523486666245
# 141.74956666646017
# 140.89593335161555

# %%
region_2_profit_final = calculate_final_profit(d2_sampled)

region_2_profit_final
# Out:
# 27182769.03452097

# %%
region_2_risk = d2total_risk/region_2_profit_final

region_2_risk
# Out:
# 0.03746796052222533

# %% [markdown]
# Q The risk isnt right so I must still be doing something wrong?
#
# Update = There are two ways I calculated risk, my way and @Dot's way. None of the regions had risk below the threshold when calculated by either method. Which one is right?

# %% [markdown]
# (Updated below)
#
# Region 1 has the lowest risk using my method and the second lowest using @Dot's method, it also has the highest profit. It seems to be the most attractive region
#
# New update: Since regions 0, and 2 are the only regions with risk of losses below 2.5 percent(cell 64,70), and region 2 has the higher profit of the two(cell 59,61). This is seemingly the best region to drill at, but I got a little confused when region 0 has a higher average profit after bootstrapping(cell 77,84)

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 3 </b>
#
# Let's first make sure the profit function works properly. When we identify the error, everything will become super clear :)
#
# </div>

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 2 </b>
#
#
# - Please do not use sorted dataframes because we sort data in the revenue function.
#
#
# - Sample 500 points here, not in the profit funtion. Then call the profit function.
#
#
# - Don't forget about other regions :)
#
# </div>

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment </b>
#
# Isn't it strange that you get almost the same values?
#
#
# - We need to sample 500 points.
#
#
#
# - We then need to estimate profit.
#
#
#
# - Save profit value in some array.
#
#
# - After you finish bootstrapping, calculate the statistics. For instance, you need to update the way you estimate risk. Risk is the share of negative profit values.
#
#
# - Repeat the process for the other two regions.
#
#
# - Choose the best region. </div>

# %% [markdown]
#  #Conclusion
#
#
# Region one is the only region where the risk is below the threshold of 2.5%. It is actually only .2 of a percent!We are 95% confident that the mean profit will fall between the range of 1,138,017.2 to 9,323,048.74 USD. When calculated after bootstrapping we have an actual value for it which turns out to be 5,150,904.73 USD (cell 66).

# %% [markdown]
# ##will update conclusion when everything is working
#
# ##updated conclusion
# In summary the most attractive region to drill at is region 1. The MSE for this region is: 0.798 and the RMSE is  0.893. This is the lowest mean squared error, and root mean square error of the three regions according to the Linear regression model(cell 31)
#
#
# MSE = 0.7976263360391157
# RMSE = 0.893099286775617

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment 5 </h2>
#
#
# Yes, we can conclude that region  #1 is the best choice.
#
#
# By the way, add space after the `#` sign to make titles work :)</div>

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment </b>
#
#
# > In summary the most attractive region to drill at is region 0
#
#
# You did not even check the other two :) As far as I understand, you rely on just one prediction in the code cell #35.
# </div>
